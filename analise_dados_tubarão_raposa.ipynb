# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabela-Silverio-Cardoso-Pereira/Cola-prova/blob/master/analise_dados_tubar%C3%A3o_raposa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_shark.csv", sep="\t", on_bad_lines="skip")

# %%
#on bad line = ignora as linhas com falhas

# %%
df.head()
# Out:
#       gbifID                            datasetKey  \
# 0   90101059  8598edb6-f762-11e1-a439-00145eb45e9a
# 1  891332072  e6acc36b-4149-4458-a26f-17fbeb0df90b
# 2  891329851  e6acc36b-4149-4458-a26f-17fbeb0df90b
# 3  864486977  197908d0-5565-11d8-b290-b8a03c50a862
# 4  864486952  197908d0-5565-11d8-b290-b8a03c50a862
#
#                                         occurrenceID   kingdom    phylum  \
# 0                                                NaN  Animalia  Chordata
# 1  URI:catalog:ROM:Vertebrate Palaeontology-Recen...  Animalia  Chordata
# 2  URI:catalog:ROM:Vertebrate Palaeontology-Recen...  Animalia  Chordata
# 3                     FishBase:Occurrence:MOVI 31302  Animalia  Chordata
# 4                     FishBase:Occurrence:MOVI 30451  Animalia  Chordata
#
#             class        order     family    genus                species  \
# 0  Elasmobranchii  Lamniformes  Alopiidae  Alopias  Alopias superciliosus
# ...

# %%
df.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
df.shape
# Out:
# (1445, 50)

# %%
df.info
# Out:
# <bound method DataFrame.info of           gbifID                            datasetKey  \
# 0       90101059  8598edb6-f762-11e1-a439-00145eb45e9a
# 1      891332072  e6acc36b-4149-4458-a26f-17fbeb0df90b
# 2      891329851  e6acc36b-4149-4458-a26f-17fbeb0df90b
# 3      864486977  197908d0-5565-11d8-b290-b8a03c50a862
# 4      864486952  197908d0-5565-11d8-b290-b8a03c50a862
# ...          ...                                   ...
# 1440  1054750916  7a25f7aa-03fb-4322-aaeb-66719e1a9527
# 1441  1054711536  7a25f7aa-03fb-4322-aaeb-66719e1a9527
# 1442  1054697586  7a25f7aa-03fb-4322-aaeb-66719e1a9527
# 1443  1054659751  7a25f7aa-03fb-4322-aaeb-66719e1a9527
# 1444  1054649324  7a25f7aa-03fb-4322-aaeb-66719e1a9527
#
#                                            occurrenceID   kingdom    phylum  \
# 0                                                   NaN  Animalia  Chordata
# 1     URI:catalog:ROM:Vertebrate Palaeontology-Recen...  Animalia  Chordata
# ...

# %%
df.isnull().sum()
# Out:
# gbifID                                 0
# datasetKey                             0
# occurrenceID                         255
# kingdom                                0
# phylum                                 0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# infraspecificEpithet                1445
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                16
# verbatimScientificNameAuthorship     752
# countryCode                          272
# locality                            1208
# stateProvince                       1271
# occurrenceStatus                       0
# individualCount                     1226
# publishingOrgKey                       0
# decimalLatitude                      367
# decimalLongitude                     367
# ...

# %%
isnull = (df.isnull().sum() / len(df)) * 100 #mostra a porcentagem de nulos
print(isnull)
# Out:
# gbifID                               0.000000
# datasetKey                           0.000000
# occurrenceID                        17.647059
# kingdom                              0.000000
# phylum                               0.000000
# class                                0.000000
# order                                0.000000
# family                               0.000000
# genus                                0.000000
# species                              0.000000
# taxonRank                            0.000000
# scientificName                       0.000000
# verbatimScientificName               1.107266
# verbatimScientificNameAuthorship    52.041522
# countryCode                         18.823529
# locality                            83.598616
# stateProvince                       87.958478
# occurrenceStatus                     0.000000
# individualCount                     84.844291
# publishingOrgKey                     0.000000
# ...

# %%
#apagando colunas pratimente nulas
df = df.drop(columns=[
    "mediaType",
    "establishmentMeans",
    "typeStatus",
    "dateIdentified",
    "recordNumber",
    "depthAccuracy",
    "elevationAccuracy",
    "elevation",
    "coordinatePrecision",
    "infraspecificEpithet"
])

# %%
df.nunique()
# Out:
# gbifID                              1445
# datasetKey                            92
# occurrenceID                        1180
# kingdom                                1
# phylum                                 1
# class                                  1
# order                                  1
# family                                 1
# genus                                  1
# species                                1
# infraspecificEpithet                   0
# taxonRank                              2
# scientificName                         4
# verbatimScientificName                13
# verbatimScientificNameAuthorship      11
# countryCode                           69
# locality                             134
# stateProvince                         59
# occurrenceStatus                       2
# individualCount                       14
# publishingOrgKey                      65
# decimalLatitude                      504
# decimalLongitude                     508
# ...

# %%
contryCode = df["countryCode"].value_counts().head(60) #primeiros 60 paises registrados (mudar dps para um top algum valor )
print(contryCode)
# Out:
# countryCode
# CL    344
# ID    142
# US     80
# OM     41
# NG     40
# IN     34
# FO     29
# CI     28
# NO     27
# GH     26
# GB     26
# MX     25
# AU     22
# GA     22
# SL     19
# BR     19
# CM     16
# LR     16
# JP     15
# ZZ     13
# GN     11
# DE     10
# ZA      9
# SN      9
# GR      8
# SJ      7
# ES      7
# CO      7
# GW      7
# GQ      6
# CG      6
# NC      6
# NL      6
# TW      5
# IL      5
# CU      5
# MA      5
# BJ      4
# TG      4
# FR      4
# NZ      4
# PA      4
# AO      4
# PH      3
# MG      3
# DK      3
# CD      3
# RE      3
# EC      3
# GL      3
# CR      3
# CN      2
# VN      2
# SG      2
# MY      2
# IS      1
# PR      1
# BS      1
# KR      1
# LY      1
# Name: count, dtype: int64

# %%
provincia = df["stateProvince"].value_counts().head(10)
print(provincia)
# Out:
# stateProvince
# Florida                    20
# California                 13
# North Carolina              8
# British Columbia            8
# Louisiana                   8
# Chiapas                     7
# Rs                          7
# Northern Atlantic Ocean     6
# New South Wales             6
# Tasmania                    5
# Name: count, dtype: int64

# %%
df["eventDate"].value_counts().head(10)
# Out:
# eventDate
# 1972-03-06          28
# 1972-08-24          11
# 1972-04-05           9
# 1972-03-10           9
# 2004-03-02           8
# 2021-05-19T13:00     8
# 1964-03-21           8
# 2011-09-10           8
# 2011-09-13           8
# 1964-05-07           8
# Name: count, dtype: int64

# %%
#registros por ano
anos = df["year"].value_counts().sort_index()
print(anos)
# Out:
# year
# 1860.0     1
# 1879.0     1
# 1929.0     1
# 1935.0     2
# 1937.0     1
#           ..
# 2022.0    20
# 2023.0    13
# 2024.0    10
# 2025.0     1
# 2026.0     3
# Name: count, Length: 65, dtype: int64

# %%
grafico_anos = df["year"].value_counts().sort_index().plot() #.plot (faz os gráficos)
print(grafico_anos)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
df.plot.scatter(
    x="decimalLongitude",
    y="decimalLatitude"
)
# Out:
# <Axes: xlabel='decimalLongitude', ylabel='decimalLatitude'>
